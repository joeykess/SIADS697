# %%
# Import useful packages
import os
import time
import pandas as pd
# Suppressing some warnings in pandas
pd.options.mode.chained_assignment = None
import numpy as np
import glob
import matplotlib.pyplot as plt
import yfinance as yf
from datetime import datetime, date, time, timedelta
from ta import add_all_ta_features

# Importing our self-created functions
from feature_creation import *
from portfolio import *

# Needed to scrap the web
import requests 
from bs4 import BeautifulSoup

# Importing for plotting
import plotly.express as px
import plotly.graph_objects as go
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
from jupyter_dash import JupyterDash
import dash_table
import dash_bootstrap_components as dbc

# %%
# Create stock_df to get tickers
stock_df = daily_features()

stock_df.head()
# Out:
#             Adj Close     Close  Close_adj  Dividends      High  High_adj  \
# Date
# 1990-02-16   0.056967  0.056967   0.077257        0.0  0.058887  0.079861
# 1990-02-20   0.058887  0.058887   0.079861        0.0  0.058887  0.079861
# 1990-02-21   0.057607  0.057607   0.078125        0.0  0.058247  0.078993
# 1990-02-22   0.058247  0.058247   0.078993        0.0  0.060167  0.081597
# 1990-02-23   0.057927  0.057927   0.078559        0.0  0.058887  0.079861
#
#                  Low   Low_adj  Open  Open_adj  Stock Splits       Volume  \
# Date
# 1990-02-16  0.054407  0.073785   0.0       0.0           0.0  940636800.0
# 1990-02-20  0.055047  0.074653   0.0       0.0           0.0  151862400.0
# 1990-02-21  0.055687  0.075521   0.0       0.0           0.0   70531200.0
# 1990-02-22  0.058247  0.078993   0.0       0.0           0.0   45216000.0
# 1990-02-23  0.057607  0.078125   0.0       0.0           0.0   44697600.0
#
#                 sector ticker     SMA_5  SMA_15  SMA_ratio  SD  upperband  \
# Date
# 1990-02-16  Technology   CSCO       NaN     NaN        NaN NaN        NaN
# 1990-02-20  Technology   CSCO       NaN     NaN        NaN NaN        NaN
# 1990-02-21  Technology   CSCO       NaN     NaN        NaN NaN        NaN
# 1990-02-22  Technology   CSCO       NaN     NaN        NaN NaN        NaN
# 1990-02-23  Technology   CSCO  0.057927     NaN        NaN NaN        NaN
#
#             lowerband
# Date
# 1990-02-16        NaN
# 1990-02-20        NaN
# 1990-02-21        NaN
# 1990-02-22        NaN
# 1990-02-23        NaN

# %%
stock_df[stock_df['ticker']=='CSCO']['sector'].unique()[0]
# Out:
# 'Technology'

# %%
# Creating list of tickers to scrap sentiment for (should be entire S&P 500)
tickers = list(stock_df.ticker.unique())

# %%
# Initializing scraping capabilities for sentdex on last 30 day sentiment
res = requests.get('http://www.sentdex.com/financial-analysis/?tf=30d')
soup = BeautifulSoup(res.text)
table = soup.find_all('tr')

# %%
# Initialize empty lists to store stock symbol, sentiment and mentions
stock = []
sentiment = []
mentions = []
sentiment_trend = []

# %%
# Use try and except blocks to mitigate missing data
for ticker in table:
    ticker_info = ticker.find_all('td')
    
    try:
        stock.append(ticker_info[0].get_text())
    except:
        stock.append(None)
    try:
        sentiment.append(ticker_info[3].get_text())
    except:
        sentiment.append(None)
    try:
        mentions.append(ticker_info[2].get_text())
    except:
        mentions.append(None)
    try:
        if (ticker_info[4].find('span',{"class":"glyphicon  glyphicon-chevron-up"})):
            sentiment_trend.append('up')
        else:
            sentiment_trend.append('down')
    except:
        sentiment_trend.append(None)

# %%
sentiment_df = pd.DataFrame(
    data={'Ticker': stock,
     'Sentiment': sentiment,
     'Mentions': mentions,
     'Trend': sentiment_trend,
    },
    dtype=str)

# %%
sentiment_df.head()
# Out:
#   Ticker  Sentiment Mentions Trend
# 0   None       None     None  None
# 1  SP500  very good   124814  down
# 2    NOK  very good     8996  down
# 3    SNE       good     1616  down
# 4    MAT  very good     1309  down

# %%
tick_sector_df = stock_df.groupby(['ticker', 'sector']).count().reset_index()[['ticker','sector']]

# %%
# Adding sector to sentiment_df for filtering purposes
sentiment_df2 = sentiment_df.merge(tick_sector_df,how='left',left_on='Ticker',right_on='ticker')
sentiment_df2 = sentiment_df2[sentiment_df2['ticker'].notna()]

sentiment_df2['Mentions'] = sentiment_df2['Mentions'].astype('int')

sentiment_df2.head()
# Out:
#    Ticker  Sentiment  Mentions Trend ticker                  sector
# 5     LEG  very good       761  down    LEG       Consumer Cyclical
# 6       K  very good       659  down      K      Consumer Defensive
# 8     AIG       good       549  down    AIG      Financial Services
# 12   NWSA       good       430  down   NWSA  Communication Services
# 13   HBAN       good       416  down   HBAN      Financial Services

# %%
# Looks like we are missing quite a few big tickers...
tick_sector_df[tick_sector_df['ticker']=='SNE']
# Out:
# Empty DataFrame
# Columns: [ticker, sector]
# Index: []

# %%
# Saving data to CSV for loading in dashboard
sentiment_df2.to_csv('assets/models/tyler_rf_daily_update/sentiment_analysis.csv',index=False)

# %%
app = JupyterDash(__name__,external_stylesheets=[dbc.themes.SUPERHERO])

df = sentiment_df2[sentiment_df2['sector']=='Financial Services'].nlargest(10,'Mentions')[['Ticker','Sentiment','Trend','Mentions']]

app.layout = html.Div([
    dash_table.DataTable(
        id='sentiment_table',
        data=df.to_dict('records'),
        columns=[{"name": i, "id": i} for i in df.columns],
        style_cell=dict(textAlign='left'),
        style_header=dict(backgroundColor="#191970",color='white'),
        style_data=dict(backgroundColor="gray",color='black'),
        
        # Setting conditional styles for sentiment and trends
         style_data_conditional=[
            {'if': {'filter_query': '{Sentiment} = "good" || {Sentiment} = "very good"','column_id': 'Sentiment'},
                'color': '#03CD1E'},
            {'if': {'filter_query': '{Sentiment_Trend} = "down"','column_id': 'Sentiment_Trend'},
                'color': '#FF0000'},
            {'if': {'filter_query': '{Sentiment_Trend} = "up"','column_id': 'Sentiment_Trend'},
                'color': '#03CD1E'}],
        
        style_as_list_view=True
    )
])

app.run_server(mode='inline',port=8090)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8090/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# ---------------------------------------------------------------------------
# NotFound                                  Traceback (most recent call last)
# ~/Documents/Grad School/SIADS697/venv/lib/python3.7/site-packages/flask/app.py in full_dispatch_request(self=<Flask '__main__'>)
#    1511             rv = self.preprocess_request()
#    1512             if rv is None:
# -> 1513                 rv = self.dispatch_request()
#         rv = None
#         self.dispatch_request = <bound method Flask.dispatch_request of <Flask '__main__'>>
#    1514         except Exception as e:
#    1515             rv = self.handle_user_exception(e)
#
# ~/Documents/Grad School/SIADS697/venv/lib/python3.7/site-packages/flask/app.py in dispatch_request(self=<Flask '__main__'>)
#    1497             return self.make_default_options_response()
#    1498         # otherwise dispatch to the handler for that endpoint
# -> 1499         return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#         self.ensure_sync = <bound method Flask.ensure_sync of <Flask '__main__'>>
#         self.view_functions = {'static': <function Flask.__init__.<locals>.<lambda> at 0x7ffcb743d320>, '_dash_assets.static': <bound method Scaffold.send_static_file of <Blueprint '_dash_assets'>>, '/_dash-component-suites/<string:package_name>/<path:fingerprinted_path>': <bound method Dash.serve_component_suites of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/_dash-layout': <bound method Dash.serve_layout of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/_dash-dependencies': <bound method Dash.dependencies of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/_dash-update-component': <bound method Dash.dispatch of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/_reload-hash': <bound method Dash.serve_reload_hash of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/_favicon.ico': <function Dash._serve_default_favicon at 0x7ffcb4815050>, '/': <bound method Dash.index of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/<path:path>': <bound method Dash.index of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, 'shutdown': <function JupyterDash.__init__.<locals>.shutdown at 0x7ffca69c1e60>, 'alive': <function JupyterDash.__init__.<locals>.alive at 0x7ffcb6748b90>}
#         rule.endpoint = '_dash_assets.static'
#         req.view_args = {'filename': 'animate.min.css'}
#    1500
#    1501     def full_dispatch_request(self) -> Response:
#
# ~/Documents/Grad School/SIADS697/venv/lib/python3.7/site-packages/flask/scaffold.py in send_static_file(
#     self=<Blueprint '_dash_assets'>,
#     filename='animate.min.css'
# )
#     327         max_age = self.get_send_file_max_age(filename)
#     328         return send_from_directory(
# --> 329             t.cast(str, self.static_folder), filename, max_age=max_age
#         global t.cast = <function cast at 0x7ffcaf019830>
#         global str = undefined
#         self.static_folder = '/Users/tylerdrumheller/Documents/Grad School/SIADS697/assets'
#         filename = 'animate.min.css'
#         max_age = None
#     330         )
#     331
#
# ~/Documents/Grad School/SIADS697/venv/lib/python3.7/site-packages/flask/helpers.py in send_from_directory(
#     directory='/Users/tylerdrumheller/Documents/Grad School/SIADS697/assets',
#     path='animate.min.css',
#     filename=None,
#     **kwargs={'max_age': None}
# )
#     699
#     700     return werkzeug.utils.send_from_directory(  # type: ignore
# --> 701         directory, path, **_prepare_send_file_kwargs(**kwargs)
#         directory = '/Users/tylerdrumheller/Documents/Grad School/SIADS697/assets'
#         path = 'animate.min.css'
#         global _prepare_send_file_kwargs = <function _prepare_send_file_kwargs at 0x7ffcb471f680>
#         kwargs = {'max_age': None}
#     702     )
#     703
#
# ~/Documents/Grad School/SIADS697/venv/lib/python3.7/site-packages/werkzeug/utils.py in send_from_directory(
#     directory='/Users/tylerdrumheller/Documents/Grad School/SIADS697/assets',
#     path='/Users/tylerdrumheller/Documents/Grad School/SIADS697/assets/animate.min.css',
#     environ={'HTTP_ACCEPT': 'text/css,*/*;q=0.1', 'HTTP_ACCEPT_ENCODING': 'gzip, deflate, br', 'HTTP_ACCEPT_LANGUAGE': 'en-US,en;q=0.9', 'HTTP_CONNECTION': 'keep-alive', 'HTTP_HOST': '127.0.0.1:8090', 'HTTP_REFERER': 'http://127.0.0.1:8090/assets/style.css?m=1627959004.9830096', 'HTTP_SEC_CH_UA': '"Chromium";v="92", " Not A;Brand";v="99", "Google Chrome";v="92"', 'HTTP_SEC_CH_UA_MOBILE': '?0', 'HTTP_SEC_FETCH_DEST': 'style', 'HTTP_SEC_FETCH_MODE': 'no-cors', ...},
#     **kwargs={'_root_path': '/Users/tylerdrumheller/Documents/Grad School/SIADS697', 'download_name': None, 'etag': None, 'max_age': <bound method Scaffold.get_send_file_max_age of <Flask '__main__'>>, 'response_class': <class 'flask.wrappers.Response'>, 'use_x_sendfile': False}
# )
#     839     try:
#     840         if not os.path.isfile(path):
# --> 841             raise NotFound()
#         global NotFound = <class 'werkzeug.exceptions.NotFound'>
#     842     except ValueError:
#     843         # path contains null byte on Python < 3.8
#
# NotFound: 404 Not Found: The requested URL was not found on the server. If you entered the URL manually please check your spelling and try again.
#
# ---------------------------------------------------------------------------
# NotFound                                  Traceback (most recent call last)
# ~/Documents/Grad School/SIADS697/venv/lib/python3.7/site-packages/flask/app.py in full_dispatch_request(self=<Flask '__main__'>)
#    1511             rv = self.preprocess_request()
#    1512             if rv is None:
# -> 1513                 rv = self.dispatch_request()
#         rv = None
#         self.dispatch_request = <bound method Flask.dispatch_request of <Flask '__main__'>>
#    1514         except Exception as e:
#    1515             rv = self.handle_user_exception(e)
#
# ~/Documents/Grad School/SIADS697/venv/lib/python3.7/site-packages/flask/app.py in dispatch_request(self=<Flask '__main__'>)
#    1497             return self.make_default_options_response()
#    1498         # otherwise dispatch to the handler for that endpoint
# -> 1499         return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#         self.ensure_sync = <bound method Flask.ensure_sync of <Flask '__main__'>>
#         self.view_functions = {'static': <function Flask.__init__.<locals>.<lambda> at 0x7ffcb743d320>, '_dash_assets.static': <bound method Scaffold.send_static_file of <Blueprint '_dash_assets'>>, '/_dash-component-suites/<string:package_name>/<path:fingerprinted_path>': <bound method Dash.serve_component_suites of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/_dash-layout': <bound method Dash.serve_layout of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/_dash-dependencies': <bound method Dash.dependencies of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/_dash-update-component': <bound method Dash.dispatch of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/_reload-hash': <bound method Dash.serve_reload_hash of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/_favicon.ico': <function Dash._serve_default_favicon at 0x7ffcb4815050>, '/': <bound method Dash.index of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/<path:path>': <bound method Dash.index of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, 'shutdown': <function JupyterDash.__init__.<locals>.shutdown at 0x7ffca69c1e60>, 'alive': <function JupyterDash.__init__.<locals>.alive at 0x7ffcb6748b90>}
#         rule.endpoint = '_dash_assets.static'
#         req.view_args = {'filename': 'meanmenu.css'}
#    1500
#    1501     def full_dispatch_request(self) -> Response:
#
# ~/Documents/Grad School/SIADS697/venv/lib/python3.7/site-packages/flask/scaffold.py in send_static_file(
#     self=<Blueprint '_dash_assets'>,
#     filename='meanmenu.css'
# )
#     327         max_age = self.get_send_file_max_age(filename)
#     328         return send_from_directory(
# --> 329             t.cast(str, self.static_folder), filename, max_age=max_age
#         global t.cast = <function cast at 0x7ffcaf019830>
#         global str = undefined
#         self.static_folder = '/Users/tylerdrumheller/Documents/Grad School/SIADS697/assets'
#         filename = 'meanmenu.css'
#         max_age = None
#     330         )
#     331
#
# ~/Documents/Grad School/SIADS697/venv/lib/python3.7/site-packages/flask/helpers.py in send_from_directory(
#     directory='/Users/tylerdrumheller/Documents/Grad School/SIADS697/assets',
#     path='meanmenu.css',
#     filename=None,
#     **kwargs={'max_age': None}
# )
#     699
#     700     return werkzeug.utils.send_from_directory(  # type: ignore
# --> 701         directory, path, **_prepare_send_file_kwargs(**kwargs)
#         directory = '/Users/tylerdrumheller/Documents/Grad School/SIADS697/assets'
#         path = 'meanmenu.css'
#         global _prepare_send_file_kwargs = <function _prepare_send_file_kwargs at 0x7ffcb471f680>
#         kwargs = {'max_age': None}
#     702     )
#     703
#
# ~/Documents/Grad School/SIADS697/venv/lib/python3.7/site-packages/werkzeug/utils.py in send_from_directory(
#     directory='/Users/tylerdrumheller/Documents/Grad School/SIADS697/assets',
#     path='/Users/tylerdrumheller/Documents/Grad School/SIADS697/assets/meanmenu.css',
#     environ={'HTTP_ACCEPT': 'text/css,*/*;q=0.1', 'HTTP_ACCEPT_ENCODING': 'gzip, deflate, br', 'HTTP_ACCEPT_LANGUAGE': 'en-US,en;q=0.9', 'HTTP_CONNECTION': 'keep-alive', 'HTTP_HOST': '127.0.0.1:8090', 'HTTP_REFERER': 'http://127.0.0.1:8090/assets/style.css?m=1627959004.9830096', 'HTTP_SEC_CH_UA': '"Chromium";v="92", " Not A;Brand";v="99", "Google Chrome";v="92"', 'HTTP_SEC_CH_UA_MOBILE': '?0', 'HTTP_SEC_FETCH_DEST': 'style', 'HTTP_SEC_FETCH_MODE': 'no-cors', ...},
#     **kwargs={'_root_path': '/Users/tylerdrumheller/Documents/Grad School/SIADS697', 'download_name': None, 'etag': None, 'max_age': <bound method Scaffold.get_send_file_max_age of <Flask '__main__'>>, 'response_class': <class 'flask.wrappers.Response'>, 'use_x_sendfile': False}
# )
#     839     try:
#     840         if not os.path.isfile(path):
# --> 841             raise NotFound()
#         global NotFound = <class 'werkzeug.exceptions.NotFound'>
#     842     except ValueError:
#     843         # path contains null byte on Python < 3.8
#
# NotFound: 404 Not Found: The requested URL was not found on the server. If you entered the URL manually please check your spelling and try again.
#
# ---------------------------------------------------------------------------
# NotFound                                  Traceback (most recent call last)
# ~/Documents/Grad School/SIADS697/venv/lib/python3.7/site-packages/flask/app.py in full_dispatch_request(self=<Flask '__main__'>)
#    1511             rv = self.preprocess_request()
#    1512             if rv is None:
# -> 1513                 rv = self.dispatch_request()
#         rv = None
#         self.dispatch_request = <bound method Flask.dispatch_request of <Flask '__main__'>>
#    1514         except Exception as e:
#    1515             rv = self.handle_user_exception(e)
#
# ~/Documents/Grad School/SIADS697/venv/lib/python3.7/site-packages/flask/app.py in dispatch_request(self=<Flask '__main__'>)
#    1497             return self.make_default_options_response()
#    1498         # otherwise dispatch to the handler for that endpoint
# -> 1499         return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#         self.ensure_sync = <bound method Flask.ensure_sync of <Flask '__main__'>>
#         self.view_functions = {'static': <function Flask.__init__.<locals>.<lambda> at 0x7ffcb743d320>, '_dash_assets.static': <bound method Scaffold.send_static_file of <Blueprint '_dash_assets'>>, '/_dash-component-suites/<string:package_name>/<path:fingerprinted_path>': <bound method Dash.serve_component_suites of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/_dash-layout': <bound method Dash.serve_layout of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/_dash-dependencies': <bound method Dash.dependencies of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/_dash-update-component': <bound method Dash.dispatch of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/_reload-hash': <bound method Dash.serve_reload_hash of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/_favicon.ico': <function Dash._serve_default_favicon at 0x7ffcb4815050>, '/': <bound method Dash.index of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/<path:path>': <bound method Dash.index of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, 'shutdown': <function JupyterDash.__init__.<locals>.shutdown at 0x7ffca69c1e60>, 'alive': <function JupyterDash.__init__.<locals>.alive at 0x7ffcb6748b90>}
#         rule.endpoint = '_dash_assets.static'
#         req.view_args = {'filename': 'normalize.css'}
#    1500
#    1501     def full_dispatch_request(self) -> Response:
#
# ~/Documents/Grad School/SIADS697/venv/lib/python3.7/site-packages/flask/scaffold.py in send_static_file(
#     self=<Blueprint '_dash_assets'>,
#     filename='normalize.css'
# )
#     327         max_age = self.get_send_file_max_age(filename)
#     328         return send_from_directory(
# --> 329             t.cast(str, self.static_folder), filename, max_age=max_age
#         global t.cast = <function cast at 0x7ffcaf019830>
#         global str = undefined
#         self.static_folder = '/Users/tylerdrumheller/Documents/Grad School/SIADS697/assets'
#         filename = 'normalize.css'
#         max_age = None
#     330         )
#     331
#
# ~/Documents/Grad School/SIADS697/venv/lib/python3.7/site-packages/flask/helpers.py in send_from_directory(
#     directory='/Users/tylerdrumheller/Documents/Grad School/SIADS697/assets',
#     path='normalize.css',
#     filename=None,
#     **kwargs={'max_age': None}
# )
#     699
#     700     return werkzeug.utils.send_from_directory(  # type: ignore
# --> 701         directory, path, **_prepare_send_file_kwargs(**kwargs)
#         directory = '/Users/tylerdrumheller/Documents/Grad School/SIADS697/assets'
#         path = 'normalize.css'
#         global _prepare_send_file_kwargs = <function _prepare_send_file_kwargs at 0x7ffcb471f680>
#         kwargs = {'max_age': None}
#     702     )
#     703
#
# ~/Documents/Grad School/SIADS697/venv/lib/python3.7/site-packages/werkzeug/utils.py in send_from_directory(
#     directory='/Users/tylerdrumheller/Documents/Grad School/SIADS697/assets',
#     path='/Users/tylerdrumheller/Documents/Grad School/SIADS697/assets/normalize.css',
#     environ={'HTTP_ACCEPT': 'text/css,*/*;q=0.1', 'HTTP_ACCEPT_ENCODING': 'gzip, deflate, br', 'HTTP_ACCEPT_LANGUAGE': 'en-US,en;q=0.9', 'HTTP_CONNECTION': 'keep-alive', 'HTTP_HOST': '127.0.0.1:8090', 'HTTP_REFERER': 'http://127.0.0.1:8090/assets/style.css?m=1627959004.9830096', 'HTTP_SEC_CH_UA': '"Chromium";v="92", " Not A;Brand";v="99", "Google Chrome";v="92"', 'HTTP_SEC_CH_UA_MOBILE': '?0', 'HTTP_SEC_FETCH_DEST': 'style', 'HTTP_SEC_FETCH_MODE': 'no-cors', ...},
#     **kwargs={'_root_path': '/Users/tylerdrumheller/Documents/Grad School/SIADS697', 'download_name': None, 'etag': None, 'max_age': <bound method Scaffold.get_send_file_max_age of <Flask '__main__'>>, 'response_class': <class 'flask.wrappers.Response'>, 'use_x_sendfile': False}
# )
#     839     try:
#     840         if not os.path.isfile(path):
# --> 841             raise NotFound()
#         global NotFound = <class 'werkzeug.exceptions.NotFound'>
#     842     except ValueError:
#     843         # path contains null byte on Python < 3.8
#
# NotFound: 404 Not Found: The requested URL was not found on the server. If you entered the URL manually please check your spelling and try again.
#
# ---------------------------------------------------------------------------
# NotFound                                  Traceback (most recent call last)
# ~/Documents/Grad School/SIADS697/venv/lib/python3.7/site-packages/flask/app.py in full_dispatch_request(self=<Flask '__main__'>)
#    1511             rv = self.preprocess_request()
#    1512             if rv is None:
# -> 1513                 rv = self.dispatch_request()
#         rv = None
#         self.dispatch_request = <bound method Flask.dispatch_request of <Flask '__main__'>>
#    1514         except Exception as e:
#    1515             rv = self.handle_user_exception(e)
#
# ~/Documents/Grad School/SIADS697/venv/lib/python3.7/site-packages/flask/app.py in dispatch_request(self=<Flask '__main__'>)
#    1497             return self.make_default_options_response()
#    1498         # otherwise dispatch to the handler for that endpoint
# -> 1499         return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#         self.ensure_sync = <bound method Flask.ensure_sync of <Flask '__main__'>>
#         self.view_functions = {'static': <function Flask.__init__.<locals>.<lambda> at 0x7ffcb743d320>, '_dash_assets.static': <bound method Scaffold.send_static_file of <Blueprint '_dash_assets'>>, '/_dash-component-suites/<string:package_name>/<path:fingerprinted_path>': <bound method Dash.serve_component_suites of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/_dash-layout': <bound method Dash.serve_layout of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/_dash-dependencies': <bound method Dash.dependencies of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/_dash-update-component': <bound method Dash.dispatch of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/_reload-hash': <bound method Dash.serve_reload_hash of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/_favicon.ico': <function Dash._serve_default_favicon at 0x7ffcb4815050>, '/': <bound method Dash.index of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/<path:path>': <bound method Dash.index of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, 'shutdown': <function JupyterDash.__init__.<locals>.shutdown at 0x7ffca69c1e60>, 'alive': <function JupyterDash.__init__.<locals>.alive at 0x7ffcb6748b90>}
#         rule.endpoint = '_dash_assets.static'
#         req.view_args = {'filename': 'slick.css'}
#    1500
#    1501     def full_dispatch_request(self) -> Response:
#
# ~/Documents/Grad School/SIADS697/venv/lib/python3.7/site-packages/flask/scaffold.py in send_static_file(
#     self=<Blueprint '_dash_assets'>,
#     filename='slick.css'
# )
#     327         max_age = self.get_send_file_max_age(filename)
#     328         return send_from_directory(
# --> 329             t.cast(str, self.static_folder), filename, max_age=max_age
#         global t.cast = <function cast at 0x7ffcaf019830>
#         global str = undefined
#         self.static_folder = '/Users/tylerdrumheller/Documents/Grad School/SIADS697/assets'
#         filename = 'slick.css'
#         max_age = None
#     330         )
#     331
#
# ~/Documents/Grad School/SIADS697/venv/lib/python3.7/site-packages/flask/helpers.py in send_from_directory(
#     directory='/Users/tylerdrumheller/Documents/Grad School/SIADS697/assets',
#     path='slick.css',
#     filename=None,
#     **kwargs={'max_age': None}
# )
#     699
#     700     return werkzeug.utils.send_from_directory(  # type: ignore
# --> 701         directory, path, **_prepare_send_file_kwargs(**kwargs)
#         directory = '/Users/tylerdrumheller/Documents/Grad School/SIADS697/assets'
#         path = 'slick.css'
#         global _prepare_send_file_kwargs = <function _prepare_send_file_kwargs at 0x7ffcb471f680>
#         kwargs = {'max_age': None}
#     702     )
#     703
#
# ~/Documents/Grad School/SIADS697/venv/lib/python3.7/site-packages/werkzeug/utils.py in send_from_directory(
#     directory='/Users/tylerdrumheller/Documents/Grad School/SIADS697/assets',
#     path='/Users/tylerdrumheller/Documents/Grad School/SIADS697/assets/slick.css',
#     environ={'HTTP_ACCEPT': 'text/css,*/*;q=0.1', 'HTTP_ACCEPT_ENCODING': 'gzip, deflate, br', 'HTTP_ACCEPT_LANGUAGE': 'en-US,en;q=0.9', 'HTTP_CONNECTION': 'keep-alive', 'HTTP_HOST': '127.0.0.1:8090', 'HTTP_REFERER': 'http://127.0.0.1:8090/assets/style.css?m=1627959004.9830096', 'HTTP_SEC_CH_UA': '"Chromium";v="92", " Not A;Brand";v="99", "Google Chrome";v="92"', 'HTTP_SEC_CH_UA_MOBILE': '?0', 'HTTP_SEC_FETCH_DEST': 'style', 'HTTP_SEC_FETCH_MODE': 'no-cors', ...},
#     **kwargs={'_root_path': '/Users/tylerdrumheller/Documents/Grad School/SIADS697', 'download_name': None, 'etag': None, 'max_age': <bound method Scaffold.get_send_file_max_age of <Flask '__main__'>>, 'response_class': <class 'flask.wrappers.Response'>, 'use_x_sendfile': False}
# )
#     839     try:
#     840         if not os.path.isfile(path):
# --> 841             raise NotFound()
#         global NotFound = <class 'werkzeug.exceptions.NotFound'>
#     842     except ValueError:
#     843         # path contains null byte on Python < 3.8
#
# NotFound: 404 Not Found: The requested URL was not found on the server. If you entered the URL manually please check your spelling and try again.
#
# ---------------------------------------------------------------------------
# NotFound                                  Traceback (most recent call last)
# ~/Documents/Grad School/SIADS697/venv/lib/python3.7/site-packages/flask/app.py in full_dispatch_request(self=<Flask '__main__'>)
#    1511             rv = self.preprocess_request()
#    1512             if rv is None:
# -> 1513                 rv = self.dispatch_request()
#         rv = None
#         self.dispatch_request = <bound method Flask.dispatch_request of <Flask '__main__'>>
#    1514         except Exception as e:
#    1515             rv = self.handle_user_exception(e)
#
# ~/Documents/Grad School/SIADS697/venv/lib/python3.7/site-packages/flask/app.py in dispatch_request(self=<Flask '__main__'>)
#    1497             return self.make_default_options_response()
#    1498         # otherwise dispatch to the handler for that endpoint
# -> 1499         return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#         self.ensure_sync = <bound method Flask.ensure_sync of <Flask '__main__'>>
#         self.view_functions = {'static': <function Flask.__init__.<locals>.<lambda> at 0x7ffcb743d320>, '_dash_assets.static': <bound method Scaffold.send_static_file of <Blueprint '_dash_assets'>>, '/_dash-component-suites/<string:package_name>/<path:fingerprinted_path>': <bound method Dash.serve_component_suites of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/_dash-layout': <bound method Dash.serve_layout of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/_dash-dependencies': <bound method Dash.dependencies of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/_dash-update-component': <bound method Dash.dispatch of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/_reload-hash': <bound method Dash.serve_reload_hash of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/_favicon.ico': <function Dash._serve_default_favicon at 0x7ffcb4815050>, '/': <bound method Dash.index of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/<path:path>': <bound method Dash.index of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, 'shutdown': <function JupyterDash.__init__.<locals>.shutdown at 0x7ffca69c1e60>, 'alive': <function JupyterDash.__init__.<locals>.alive at 0x7ffcb6748b90>}
#         rule.endpoint = '_dash_assets.static'
#         req.view_args = {'filename': 'font-awesome.min.css'}
#    1500
#    1501     def full_dispatch_request(self) -> Response:
#
# ~/Documents/Grad School/SIADS697/venv/lib/python3.7/site-packages/flask/scaffold.py in send_static_file(
#     self=<Blueprint '_dash_assets'>,
#     filename='font-awesome.min.css'
# )
#     327         max_age = self.get_send_file_max_age(filename)
#     328         return send_from_directory(
# --> 329             t.cast(str, self.static_folder), filename, max_age=max_age
#         global t.cast = <function cast at 0x7ffcaf019830>
#         global str = undefined
#         self.static_folder = '/Users/tylerdrumheller/Documents/Grad School/SIADS697/assets'
#         filename = 'font-awesome.min.css'
#         max_age = None
#     330         )
#     331
#
# ~/Documents/Grad School/SIADS697/venv/lib/python3.7/site-packages/flask/helpers.py in send_from_directory(
#     directory='/Users/tylerdrumheller/Documents/Grad School/SIADS697/assets',
#     path='font-awesome.min.css',
#     filename=None,
#     **kwargs={'max_age': None}
# )
#     699
#     700     return werkzeug.utils.send_from_directory(  # type: ignore
# --> 701         directory, path, **_prepare_send_file_kwargs(**kwargs)
#         directory = '/Users/tylerdrumheller/Documents/Grad School/SIADS697/assets'
#         path = 'font-awesome.min.css'
#         global _prepare_send_file_kwargs = <function _prepare_send_file_kwargs at 0x7ffcb471f680>
#         kwargs = {'max_age': None}
#     702     )
#     703
#
# ~/Documents/Grad School/SIADS697/venv/lib/python3.7/site-packages/werkzeug/utils.py in send_from_directory(
#     directory='/Users/tylerdrumheller/Documents/Grad School/SIADS697/assets',
#     path='/Users/tylerdrumheller/Documents/Grad School/SIADS697/assets/font-awesome.min.css',
#     environ={'HTTP_ACCEPT': 'text/css,*/*;q=0.1', 'HTTP_ACCEPT_ENCODING': 'gzip, deflate, br', 'HTTP_ACCEPT_LANGUAGE': 'en-US,en;q=0.9', 'HTTP_CONNECTION': 'keep-alive', 'HTTP_HOST': '127.0.0.1:8090', 'HTTP_REFERER': 'http://127.0.0.1:8090/assets/style.css?m=1627959004.9830096', 'HTTP_SEC_CH_UA': '"Chromium";v="92", " Not A;Brand";v="99", "Google Chrome";v="92"', 'HTTP_SEC_CH_UA_MOBILE': '?0', 'HTTP_SEC_FETCH_DEST': 'style', 'HTTP_SEC_FETCH_MODE': 'no-cors', ...},
#     **kwargs={'_root_path': '/Users/tylerdrumheller/Documents/Grad School/SIADS697', 'download_name': None, 'etag': None, 'max_age': <bound method Scaffold.get_send_file_max_age of <Flask '__main__'>>, 'response_class': <class 'flask.wrappers.Response'>, 'use_x_sendfile': False}
# )
#     839     try:
#     840         if not os.path.isfile(path):
# --> 841             raise NotFound()
#         global NotFound = <class 'werkzeug.exceptions.NotFound'>
#     842     except ValueError:
#     843         # path contains null byte on Python < 3.8
#
# NotFound: 404 Not Found: The requested URL was not found on the server. If you entered the URL manually please check your spelling and try again.
#
# ---------------------------------------------------------------------------
# NotFound                                  Traceback (most recent call last)
# ~/Documents/Grad School/SIADS697/venv/lib/python3.7/site-packages/flask/app.py in full_dispatch_request(self=<Flask '__main__'>)
#    1511             rv = self.preprocess_request()
#    1512             if rv is None:
# -> 1513                 rv = self.dispatch_request()
#         rv = None
#         self.dispatch_request = <bound method Flask.dispatch_request of <Flask '__main__'>>
#    1514         except Exception as e:
#    1515             rv = self.handle_user_exception(e)
#
# ~/Documents/Grad School/SIADS697/venv/lib/python3.7/site-packages/flask/app.py in dispatch_request(self=<Flask '__main__'>)
#    1497             return self.make_default_options_response()
#    1498         # otherwise dispatch to the handler for that endpoint
# -> 1499         return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#         self.ensure_sync = <bound method Flask.ensure_sync of <Flask '__main__'>>
#         self.view_functions = {'static': <function Flask.__init__.<locals>.<lambda> at 0x7ffcb743d320>, '_dash_assets.static': <bound method Scaffold.send_static_file of <Blueprint '_dash_assets'>>, '/_dash-component-suites/<string:package_name>/<path:fingerprinted_path>': <bound method Dash.serve_component_suites of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/_dash-layout': <bound method Dash.serve_layout of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/_dash-dependencies': <bound method Dash.dependencies of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/_dash-update-component': <bound method Dash.dispatch of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/_reload-hash': <bound method Dash.serve_reload_hash of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/_favicon.ico': <function Dash._serve_default_favicon at 0x7ffcb4815050>, '/': <bound method Dash.index of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/<path:path>': <bound method Dash.index of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, 'shutdown': <function JupyterDash.__init__.<locals>.shutdown at 0x7ffca69c1e60>, 'alive': <function JupyterDash.__init__.<locals>.alive at 0x7ffcb6748b90>}
#         rule.endpoint = '_dash_assets.static'
#         req.view_args = {'filename': 'owl.carousel.min.css'}
#    1500
#    1501     def full_dispatch_request(self) -> Response:
#
# ~/Documents/Grad School/SIADS697/venv/lib/python3.7/site-packages/flask/scaffold.py in send_static_file(
#     self=<Blueprint '_dash_assets'>,
#     filename='owl.carousel.min.css'
# )
#     327         max_age = self.get_send_file_max_age(filename)
#     328         return send_from_directory(
# --> 329             t.cast(str, self.static_folder), filename, max_age=max_age
#         global t.cast = <function cast at 0x7ffcaf019830>
#         global str = undefined
#         self.static_folder = '/Users/tylerdrumheller/Documents/Grad School/SIADS697/assets'
#         filename = 'owl.carousel.min.css'
#         max_age = None
#     330         )
#     331
#
# ~/Documents/Grad School/SIADS697/venv/lib/python3.7/site-packages/flask/helpers.py in send_from_directory(
#     directory='/Users/tylerdrumheller/Documents/Grad School/SIADS697/assets',
#     path='owl.carousel.min.css',
#     filename=None,
#     **kwargs={'max_age': None}
# )
#     699
#     700     return werkzeug.utils.send_from_directory(  # type: ignore
# --> 701         directory, path, **_prepare_send_file_kwargs(**kwargs)
#         directory = '/Users/tylerdrumheller/Documents/Grad School/SIADS697/assets'
#         path = 'owl.carousel.min.css'
#         global _prepare_send_file_kwargs = <function _prepare_send_file_kwargs at 0x7ffcb471f680>
#         kwargs = {'max_age': None}
#     702     )
#     703
#
# ~/Documents/Grad School/SIADS697/venv/lib/python3.7/site-packages/werkzeug/utils.py in send_from_directory(
#     directory='/Users/tylerdrumheller/Documents/Grad School/SIADS697/assets',
#     path='/Users/tylerdrumheller/Documents/Grad School/SIADS697/assets/owl.carousel.min.css',
#     environ={'HTTP_ACCEPT': 'text/css,*/*;q=0.1', 'HTTP_ACCEPT_ENCODING': 'gzip, deflate, br', 'HTTP_ACCEPT_LANGUAGE': 'en-US,en;q=0.9', 'HTTP_CONNECTION': 'keep-alive', 'HTTP_HOST': '127.0.0.1:8090', 'HTTP_REFERER': 'http://127.0.0.1:8090/assets/style.css?m=1627959004.9830096', 'HTTP_SEC_CH_UA': '"Chromium";v="92", " Not A;Brand";v="99", "Google Chrome";v="92"', 'HTTP_SEC_CH_UA_MOBILE': '?0', 'HTTP_SEC_FETCH_DEST': 'style', 'HTTP_SEC_FETCH_MODE': 'no-cors', ...},
#     **kwargs={'_root_path': '/Users/tylerdrumheller/Documents/Grad School/SIADS697', 'download_name': None, 'etag': None, 'max_age': <bound method Scaffold.get_send_file_max_age of <Flask '__main__'>>, 'response_class': <class 'flask.wrappers.Response'>, 'use_x_sendfile': False}
# )
#     839     try:
#     840         if not os.path.isfile(path):
# --> 841             raise NotFound()
#         global NotFound = <class 'werkzeug.exceptions.NotFound'>
#     842     except ValueError:
#     843         # path contains null byte on Python < 3.8
#
# NotFound: 404 Not Found: The requested URL was not found on the server. If you entered the URL manually please check your spelling and try again.
# ---------------------------------------------------------------------------
# NotFound                                  Traceback (most recent call last)
# ~/Documents/Grad School/SIADS697/venv/lib/python3.7/site-packages/flask/app.py in full_dispatch_request(self=<Flask '__main__'>)
#    1511             rv = self.preprocess_request()
#    1512             if rv is None:
# -> 1513                 rv = self.dispatch_request()
#         rv = None
#         self.dispatch_request = <bound method Flask.dispatch_request of <Flask '__main__'>>
#    1514         except Exception as e:
#    1515             rv = self.handle_user_exception(e)
#
# ~/Documents/Grad School/SIADS697/venv/lib/python3.7/site-packages/flask/app.py in dispatch_request(self=<Flask '__main__'>)
#    1497             return self.make_default_options_response()
#    1498         # otherwise dispatch to the handler for that endpoint
# -> 1499         return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#         self.ensure_sync = <bound method Flask.ensure_sync of <Flask '__main__'>>
#         self.view_functions = {'static': <function Flask.__init__.<locals>.<lambda> at 0x7ffcb743d320>, '_dash_assets.static': <bound method Scaffold.send_static_file of <Blueprint '_dash_assets'>>, '/_dash-component-suites/<string:package_name>/<path:fingerprinted_path>': <bound method Dash.serve_component_suites of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/_dash-layout': <bound method Dash.serve_layout of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/_dash-dependencies': <bound method Dash.dependencies of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/_dash-update-component': <bound method Dash.dispatch of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/_reload-hash': <bound method Dash.serve_reload_hash of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/_favicon.ico': <function Dash._serve_default_favicon at 0x7ffcb4815050>, '/': <bound method Dash.index of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/<path:path>': <bound method Dash.index of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, 'shutdown': <function JupyterDash.__init__.<locals>.shutdown at 0x7ffca69c1e60>, 'alive': <function JupyterDash.__init__.<locals>.alive at 0x7ffcb6748b90>}
#         rule.endpoint = '_dash_assets.static'
#         req.view_args = {'filename': 'jquery.fancybox.min.css'}
#    1500
#    1501     def full_dispatch_request(self) -> Response:
#
# ~/Documents/Grad School/SIADS697/venv/lib/python3.7/site-packages/flask/scaffold.py in send_static_file(
#     self=<Blueprint '_dash_assets'>,
#     filename='jquery.fancybox.min.css'
# )
#     327         max_age = self.get_send_file_max_age(filename)
#     328         return send_from_directory(
# --> 329             t.cast(str, self.static_folder), filename, max_age=max_age
#         global t.cast = <function cast at 0x7ffcaf019830>
#         global str = undefined
#         self.static_folder = '/Users/tylerdrumheller/Documents/Grad School/SIADS697/assets'
#         filename = 'jquery.fancybox.min.css'
#         max_age = None
#     330         )
#     331
#
# ~/Documents/Grad School/SIADS697/venv/lib/python3.7/site-packages/flask/helpers.py in send_from_directory(
#     directory='/Users/tylerdrumheller/Documents/Grad School/SIADS697/assets',
#     path='jquery.fancybox.min.css',
#     filename=None,
#     **kwargs={'max_age': None}
# )
#     699
#     700     return werkzeug.utils.send_from_directory(  # type: ignore
# --> 701         directory, path, **_prepare_send_file_kwargs(**kwargs)
#         directory = '/Users/tylerdrumheller/Documents/Grad School/SIADS697/assets'
#         path = 'jquery.fancybox.min.css'
#         global _prepare_send_file_kwargs = <function _prepare_send_file_kwargs at 0x7ffcb471f680>
#         kwargs = {'max_age': None}
#     702     )
#     703
#
# ~/Documents/Grad School/SIADS697/venv/lib/python3.7/site-packages/werkzeug/utils.py in send_from_directory(
#     directory='/Users/tylerdrumheller/Documents/Grad School/SIADS697/assets',
#     path='/Users/tylerdrumheller/Documents/Grad School/SIADS697/assets/jquery.fancybox.min.css',
#     environ={'HTTP_ACCEPT': 'text/css,*/*;q=0.1', 'HTTP_ACCEPT_ENCODING': 'gzip, deflate, br', 'HTTP_ACCEPT_LANGUAGE': 'en-US,en;q=0.9', 'HTTP_CONNECTION': 'keep-alive', 'HTTP_HOST': '127.0.0.1:8090', 'HTTP_REFERER': 'http://127.0.0.1:8090/assets/style.css?m=1627959004.9830096', 'HTTP_SEC_CH_UA': '"Chromium";v="92", " Not A;Brand";v="99", "Google Chrome";v="92"', 'HTTP_SEC_CH_UA_MOBILE': '?0', 'HTTP_SEC_FETCH_DEST': 'style', 'HTTP_SEC_FETCH_MODE': 'no-cors', ...},
#     **kwargs={'_root_path': '/Users/tylerdrumheller/Documents/Grad School/SIADS697', 'download_name': None, 'etag': None, 'max_age': <bound method Scaffold.get_send_file_max_age of <Flask '__main__'>>, 'response_class': <class 'flask.wrappers.Response'>, 'use_x_sendfile': False}
# )
#     839     try:
#     840         if not os.path.isfile(path):
# --> 841             raise NotFound()
#         global NotFound = <class 'werkzeug.exceptions.NotFound'>
#     842     except ValueError:
#     843         # path contains null byte on Python < 3.8
#
# NotFound: 404 Not Found: The requested URL was not found on the server. If you entered the URL manually please check your spelling and try again.
#
#
# ---------------------------------------------------------------------------
# NotFound                                  Traceback (most recent call last)
# ~/Documents/Grad School/SIADS697/venv/lib/python3.7/site-packages/flask/app.py in full_dispatch_request(self=<Flask '__main__'>)
#    1511             rv = self.preprocess_request()
#    1512             if rv is None:
# -> 1513                 rv = self.dispatch_request()
#         rv = None
#         self.dispatch_request = <bound method Flask.dispatch_request of <Flask '__main__'>>
#    1514         except Exception as e:
#    1515             rv = self.handle_user_exception(e)
#
# ~/Documents/Grad School/SIADS697/venv/lib/python3.7/site-packages/flask/app.py in dispatch_request(self=<Flask '__main__'>)
#    1497             return self.make_default_options_response()
#    1498         # otherwise dispatch to the handler for that endpoint
# -> 1499         return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#         self.ensure_sync = <bound method Flask.ensure_sync of <Flask '__main__'>>
#         self.view_functions = {'static': <function Flask.__init__.<locals>.<lambda> at 0x7ffcb743d320>, '_dash_assets.static': <bound method Scaffold.send_static_file of <Blueprint '_dash_assets'>>, '/_dash-component-suites/<string:package_name>/<path:fingerprinted_path>': <bound method Dash.serve_component_suites of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/_dash-layout': <bound method Dash.serve_layout of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/_dash-dependencies': <bound method Dash.dependencies of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/_dash-update-component': <bound method Dash.dispatch of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/_reload-hash': <bound method Dash.serve_reload_hash of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/_favicon.ico': <function Dash._serve_default_favicon at 0x7ffcb4815050>, '/': <bound method Dash.index of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/<path:path>': <bound method Dash.index of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, 'shutdown': <function JupyterDash.__init__.<locals>.shutdown at 0x7ffca69c1e60>, 'alive': <function JupyterDash.__init__.<locals>.alive at 0x7ffcb6748b90>}
#         rule.endpoint = '_dash_assets.static'
#         req.view_args = {'filename': 'nice-select.css'}
#    1500
#    1501     def full_dispatch_request(self) -> Response:
#
# ~/Documents/Grad School/SIADS697/venv/lib/python3.7/site-packages/flask/scaffold.py in send_static_file(
#     self=<Blueprint '_dash_assets'>,
#     filename='nice-select.css'
# )
#     327         max_age = self.get_send_file_max_age(filename)
#     328         return send_from_directory(
# --> 329             t.cast(str, self.static_folder), filename, max_age=max_age
#         global t.cast = <function cast at 0x7ffcaf019830>
#         global str = undefined
#         self.static_folder = '/Users/tylerdrumheller/Documents/Grad School/SIADS697/assets'
#         filename = 'nice-select.css'
#         max_age = None
#     330         )
#     331
#
# ~/Documents/Grad School/SIADS697/venv/lib/python3.7/site-packages/flask/helpers.py in send_from_directory(
#     directory='/Users/tylerdrumheller/Documents/Grad School/SIADS697/assets',
#     path='nice-select.css',
#     filename=None,
#     **kwargs={'max_age': None}
# )
#     699
#     700     return werkzeug.utils.send_from_directory(  # type: ignore
# --> 701         directory, path, **_prepare_send_file_kwargs(**kwargs)
#         directory = '/Users/tylerdrumheller/Documents/Grad School/SIADS697/assets'
#         path = 'nice-select.css'
#         global _prepare_send_file_kwargs = <function _prepare_send_file_kwargs at 0x7ffcb471f680>
#         kwargs = {'max_age': None}
#     702     )
#     703
#
# ~/Documents/Grad School/SIADS697/venv/lib/python3.7/site-packages/werkzeug/utils.py in send_from_directory(
#     directory='/Users/tylerdrumheller/Documents/Grad School/SIADS697/assets',
#     path='/Users/tylerdrumheller/Documents/Grad School/SIADS697/assets/nice-select.css',
#     environ={'HTTP_ACCEPT': 'text/css,*/*;q=0.1', 'HTTP_ACCEPT_ENCODING': 'gzip, deflate, br', 'HTTP_ACCEPT_LANGUAGE': 'en-US,en;q=0.9', 'HTTP_CONNECTION': 'keep-alive', 'HTTP_HOST': '127.0.0.1:8090', 'HTTP_REFERER': 'http://127.0.0.1:8090/assets/style.css?m=1627959004.9830096', 'HTTP_SEC_CH_UA': '"Chromium";v="92", " Not A;Brand";v="99", "Google Chrome";v="92"', 'HTTP_SEC_CH_UA_MOBILE': '?0', 'HTTP_SEC_FETCH_DEST': 'style', 'HTTP_SEC_FETCH_MODE': 'no-cors', ...},
#     **kwargs={'_root_path': '/Users/tylerdrumheller/Documents/Grad School/SIADS697', 'download_name': None, 'etag': None, 'max_age': <bound method Scaffold.get_send_file_max_age of <Flask '__main__'>>, 'response_class': <class 'flask.wrappers.Response'>, 'use_x_sendfile': False}
# )
#     839     try:
#     840         if not os.path.isfile(path):
# --> 841             raise NotFound()
#         global NotFound = <class 'werkzeug.exceptions.NotFound'>
#     842     except ValueError:
#     843         # path contains null byte on Python < 3.8
#
# NotFound: 404 Not Found: The requested URL was not found on the server. If you entered the URL manually please check your spelling and try again.
# ---------------------------------------------------------------------------
# NotFound                                  Traceback (most recent call last)
# ~/Documents/Grad School/SIADS697/venv/lib/python3.7/site-packages/flask/app.py in full_dispatch_request(self=<Flask '__main__'>)
#    1511             rv = self.preprocess_request()
#    1512             if rv is None:
# -> 1513                 rv = self.dispatch_request()
#         rv = None
#         self.dispatch_request = <bound method Flask.dispatch_request of <Flask '__main__'>>
#    1514         except Exception as e:
#    1515             rv = self.handle_user_exception(e)
#
# ~/Documents/Grad School/SIADS697/venv/lib/python3.7/site-packages/flask/app.py in dispatch_request(self=<Flask '__main__'>)
#    1497             return self.make_default_options_response()
#    1498         # otherwise dispatch to the handler for that endpoint
# -> 1499         return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#         self.ensure_sync = <bound method Flask.ensure_sync of <Flask '__main__'>>
#         self.view_functions = {'static': <function Flask.__init__.<locals>.<lambda> at 0x7ffcb743d320>, '_dash_assets.static': <bound method Scaffold.send_static_file of <Blueprint '_dash_assets'>>, '/_dash-component-suites/<string:package_name>/<path:fingerprinted_path>': <bound method Dash.serve_component_suites of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/_dash-layout': <bound method Dash.serve_layout of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/_dash-dependencies': <bound method Dash.dependencies of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/_dash-update-component': <bound method Dash.dispatch of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/_reload-hash': <bound method Dash.serve_reload_hash of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/_favicon.ico': <function Dash._serve_default_favicon at 0x7ffcb4815050>, '/': <bound method Dash.index of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, '/<path:path>': <bound method Dash.index of <jupyter_dash.jupyter_app.JupyterDash object at 0x7ffc7ee16e50>>, 'shutdown': <function JupyterDash.__init__.<locals>.shutdown at 0x7ffca69c1e60>, 'alive': <function JupyterDash.__init__.<locals>.alive at 0x7ffcb6748b90>}
#         rule.endpoint = '_dash_assets.static'
#         req.view_args = {'filename': 'jquery-ui.css'}
#    1500
#    1501     def full_dispatch_request(self) -> Response:
#
# ~/Documents/Grad School/SIADS697/venv/lib/python3.7/site-packages/flask/scaffold.py in send_static_file(
#     self=<Blueprint '_dash_assets'>,
#     filename='jquery-ui.css'
# )
#     327         max_age = self.get_send_file_max_age(filename)
#     328         return send_from_directory(
# --> 329             t.cast(str, self.static_folder), filename, max_age=max_age
#         global t.cast = <function cast at 0x7ffcaf019830>
#         global str = undefined
#         self.static_folder = '/Users/tylerdrumheller/Documents/Grad School/SIADS697/assets'
#         filename = 'jquery-ui.css'
#         max_age = None
#     330         )
#     331
#
# ~/Documents/Grad School/SIADS697/venv/lib/python3.7/site-packages/flask/helpers.py in send_from_directory(
#     directory='/Users/tylerdrumheller/Documents/Grad School/SIADS697/assets',
#     path='jquery-ui.css',
#     filename=None,
#     **kwargs={'max_age': None}
# )
#     699
#     700     return werkzeug.utils.send_from_directory(  # type: ignore
# --> 701         directory, path, **_prepare_send_file_kwargs(**kwargs)
#         directory = '/Users/tylerdrumheller/Documents/Grad School/SIADS697/assets'
#         path = 'jquery-ui.css'
#         global _prepare_send_file_kwargs = <function _prepare_send_file_kwargs at 0x7ffcb471f680>
#         kwargs = {'max_age': None}
#     702     )
#     703
#
# ~/Documents/Grad School/SIADS697/venv/lib/python3.7/site-packages/werkzeug/utils.py in send_from_directory(
#     directory='/Users/tylerdrumheller/Documents/Grad School/SIADS697/assets',
#     path='/Users/tylerdrumheller/Documents/Grad School/SIADS697/assets/jquery-ui.css',
#     environ={'HTTP_ACCEPT': 'text/css,*/*;q=0.1', 'HTTP_ACCEPT_ENCODING': 'gzip, deflate, br', 'HTTP_ACCEPT_LANGUAGE': 'en-US,en;q=0.9', 'HTTP_CONNECTION': 'keep-alive', 'HTTP_HOST': '127.0.0.1:8090', 'HTTP_REFERER': 'http://127.0.0.1:8090/assets/style.css?m=1627959004.9830096', 'HTTP_SEC_CH_UA': '"Chromium";v="92", " Not A;Brand";v="99", "Google Chrome";v="92"', 'HTTP_SEC_CH_UA_MOBILE': '?0', 'HTTP_SEC_FETCH_DEST': 'style', 'HTTP_SEC_FETCH_MODE': 'no-cors', ...},
#     **kwargs={'_root_path': '/Users/tylerdrumheller/Documents/Grad School/SIADS697', 'download_name': None, 'etag': None, 'max_age': <bound method Scaffold.get_send_file_max_age of <Flask '__main__'>>, 'response_class': <class 'flask.wrappers.Response'>, 'use_x_sendfile': False}
# )
#     839     try:
#     840         if not os.path.isfile(path):
# --> 841             raise NotFound()
#         global NotFound = <class 'werkzeug.exceptions.NotFound'>
#     842     except ValueError:
#     843         # path contains null byte on Python < 3.8
#
# NotFound: 404 Not Found: The requested URL was not found on the server. If you entered the URL manually please check your spelling and try again.
